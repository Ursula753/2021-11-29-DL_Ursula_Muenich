# %%
import json

# %%
with open("kassel.json", "r") as file:
    data = json.load(file)

# %%
print(json.dumps(data, indent=2)) #hier sind die keys properties und types noch drin
# Out:
# {
#   "types": {
#     "Bookmark": {
#       "pluralLabel": "Bookmarks"
#     },
#     "Publication": {
#       "pluralLabel": "Publications"
#     },
#     "GoldStandardPublication": {
#       "pluralLabel": "GoldStandardPublications"
#     },
#     "GoldStandardBookmark": {
#       "pluralLabel": "GoldStandardBookmarks"
#     },
#     "Tag": {
#       "pluralLabel": "Tags"
#     },
#     "User": {
#       "pluralLabel": "Users"
#     },
#     "Sphere": {
#       "pluralLabel": "Spheres"
#     }
#   },
#   "properties": {
#     "count": {
#       "valueType": "number"
#     },
#     "date": {
#       "valueType": "date"
#     },
#     "changeDate": {
#       "valueType": "date"
#     },
#     "url": {
#       "valueType": "url"
#     },
#     "id": {
#       "valueType": "url"
#     },
#     "tags": {
#       "valueType": "item"
#     },
#     "user": {
#       "valueType": "item"
#     }
#   },
#   "items": [
#     {
#       "type": "Publication",
# ...

# %%
import requests

# %%
print(data.keys())
# Out:
# dict_keys(['types', 'properties', 'items'])

# %%
data.pop('properties', None) #key "properties" rausschmeissen
# Out:
# {'count': {'valueType': 'number'},
#  'date': {'valueType': 'date'},
#  'changeDate': {'valueType': 'date'},
#  'url': {'valueType': 'url'},
#  'id': {'valueType': 'url'},
#  'tags': {'valueType': 'item'},
#  'user': {'valueType': 'item'}}

# %%
data.pop('types', None) #key "types" rausschmeissen
# Out:
# {'Bookmark': {'pluralLabel': 'Bookmarks'},
#  'Publication': {'pluralLabel': 'Publications'},
#  'GoldStandardPublication': {'pluralLabel': 'GoldStandardPublications'},
#  'GoldStandardBookmark': {'pluralLabel': 'GoldStandardBookmarks'},
#  'Tag': {'pluralLabel': 'Tags'},
#  'User': {'pluralLabel': 'Users'},
#  'Sphere': {'pluralLabel': 'Spheres'}}

# %%
print(json.dumps(data, indent=2))
# Out:
# {
#   "items": [
#     {
#       "type": "Publication",
#       "id": "https://www.bibsonomy.org/bibtex/2a9b10dbb0f006a7a71b7449de76c49a7/brinckmann",
#       "tags": [
#         "st\u00e4dtebau",
#         "wiederaufbau"
#       ],
#       "intraHash": "a9b10dbb0f006a7a71b7449de76c49a7",
#       "interHash": "b6a59ac93ba2acb9d5498b65781270d1",
#       "label": "Kassel",
#       "user": "brinckmann",
#       "description": "Gefunden im HeBIS-Portal: http://www.portal.hebis.de/",
#       "date": "2016-03-20 16:25:19",
#       "changeDate": "2016-03-20 16:25:19",
#       "count": 1,
#       "pub-type": "article",
#       "journal": "St\u00e4dte",
#       "booktitle": "Kassel",
#       "year": " 1988 ",
#       "url": "",
#       "author": [
#         "Niels Durth, Werner; Gutschow"
#       ],
#       "authors": [
#         {
#           "first": "Niels",
#           "last": "Durth, Werner; Gutschow"
#         }
#       ],
#       "pages": "791-810",
#       "bibtexKey": "Memo148756"
# ...

# %%
with open('bibsonomy_Muenich.json', 'w') as outfile:
    json.dump(data, outfile, indent=4)
