# %%
import json

# %%
import urllib.request

# %%
import urllib.parse

# %%
url = "https://www.bibsonomy.org/json/search/kassel?items=1000"

# %%
f = urllib.request.urlopen(url)

# %%
result = f.read().decode('utf-8')

# %%
print(type(result))
# Out:
# <class 'str'>

# %%
data = json.loads(result)

# %%
print(type(data))
# Out:
# <class 'dict'>

# %%
print(json.dumps(data, indent=2))
# Out:
# {
#   "types": {
#     "Bookmark": {
#       "pluralLabel": "Bookmarks"
#     },
#     "Publication": {
#       "pluralLabel": "Publications"
#     },
#     "GoldStandardPublication": {
#       "pluralLabel": "GoldStandardPublications"
#     },
#     "GoldStandardBookmark": {
#       "pluralLabel": "GoldStandardBookmarks"
#     },
#     "Tag": {
#       "pluralLabel": "Tags"
#     },
#     "User": {
#       "pluralLabel": "Users"
#     },
#     "Sphere": {
#       "pluralLabel": "Spheres"
#     }
#   },
#   "properties": {
#     "count": {
#       "valueType": "number"
#     },
#     "date": {
#       "valueType": "date"
#     },
#     "changeDate": {
#       "valueType": "date"
#     },
#     "url": {
#       "valueType": "url"
#     },
#     "id": {
#       "valueType": "url"
#     },
#     "tags": {
#       "valueType": "item"
#     },
#     "user": {
#       "valueType": "item"
#     }
#   },
#   "items": [
#     {
#       "type": "Bookmark",
# ...

# %%
with open("kassel.json", "r") as file: #json-File laden
    data = json.load(file)

# %%
edited_items = []

# Auswahl der Informationen, die ausgewählt werden sollen:

desired_entries = ['type', 'year', 'publisher', 'author', 'label', 'url']

# %%
data.keys()
# Out:
# dict_keys(['types', 'properties', 'items'])

# %%
for item in data["items"]:

    # erstelle ein neues leeres dictionary für die Daten des Elements

    item_export = {}
    #   and len(item["user"])<4
    # für jeden gewünschten Eintrag
    # hier können Filterkriterien hinzugefügt werden (hier z.B. erschienen nach 2009 und mit weniger als 4 Usern):
    if int(item["year"])>2009:
        for entry in desired_entries:
            # ... überprüfe, ob es einen Eintrag gibt (um Fehler zu vermeiden)
            if entry in item.keys():
                # füge den Eintrag den Daten zum Element hinzu
                item_export[entry] = item[entry]
        # am Ende: füge den vollständigen (gefilterten) Eintrag der zu exportierenden Liste hinzu
        print(edited_items)
        edited_items.append(item_export)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3763/1167631029.py in <module>
# ----> 1 for item in data["items"]:
#       2
#       3     # erstelle ein neues leeres dictionary für die Daten des Elements
#       4
#       5     item_export = {}
#
# NameError: name 'data' is not defined

# %%
print(edited_items)
# Out:
# [{'type': 'Publication', 'year': '2012', 'publisher': 'Kassel University Press', 'author': ['Sebastian Böttger'], 'label': 'Ein Schauspiel in drei Akten: Der Kampf gegen Studiengebühren – 2006 bis 2008', 'url': 'http://www.upress.uni-kassel.de/katalog/abstract.php?978-3-86219-250-2'}, {'type': 'Publication', 'year': '2013', 'publisher': 'euregioverlag', 'label': 'Vom Königshof zur Stadt : Kassel im Mittelalter', 'url': 'http://deposit.d-nb.de/cgi-bin/dokserv?id=4386411&prov=M&dok_var=1&dok_ext=htm'}, {'type': 'Publication', 'year': ' 2012 ', 'author': ['Stefan Orth'], 'label': 'Kunst - Zwischen Kassel und Kabul. Was bringt die 13. Documenta?', 'url': ''}, {'type': 'Publication', 'year': '2012', 'author': ['Stefan Drößler'], 'label': 'Multimediathek - Universitätsbibliothek Kassel', 'url': ''}, {'type': 'Publication', 'year': '2012', 'author': ['Alexander Roßnagel', 'Walter Blocher', 'Christiane Borchard', 'Klaus David', 'Jan Marco Leimeister', 'Andreas Schulz'], 'label': 'Mobiles Ler
# ...

# %%
items = data['items']
print(type(items))
print(len(items))
# Out:
# <class 'list'>
# 20

# %%
publications = [item for item in items if item['type']== 'Publication']
print(len(publications))
# Out:
# 20

# %%
pubs_in_abstract = [item for item in publications if 'abstract' in item]
print(len(pubs_in_abstract))
# Out:
# 7

# %%
 # hier können Filterkriterien hinzugefügt werden (hier z.B. erschienen nach 2009 und mit weniger als 4 Usern):

# if int(item["year"])>2009 and len(item["user"])<4:
if int(item["year"])>1990:

        for entry in desired_entries:

            # ... überprüfe, ob es einen Eintrag gibt (um Fehler zu vermeiden)

            if entry in item.keys():

                # füge den Eintrag den Daten zum Element hinzu

                item_export[entry] = item[entry]
        
        # am Ende: füge den vollständigen (gefilterten) Eintrag der zu exportierenden Liste hinzu
        
        edited_items.append(item_export)

# %%
print(edited_items)
# Out:
# [{'type': 'Publication', 'year': '2012', 'publisher': 'Kassel University Press', 'author': ['Sebastian Böttger'], 'label': 'Ein Schauspiel in drei Akten: Der Kampf gegen Studiengebühren – 2006 bis 2008', 'url': 'http://www.upress.uni-kassel.de/katalog/abstract.php?978-3-86219-250-2'}, {'type': 'Publication', 'year': '2013', 'publisher': 'euregioverlag', 'label': 'Vom Königshof zur Stadt : Kassel im Mittelalter', 'url': 'http://deposit.d-nb.de/cgi-bin/dokserv?id=4386411&prov=M&dok_var=1&dok_ext=htm'}, {'type': 'Publication', 'year': ' 2012 ', 'author': ['Stefan Orth'], 'label': 'Kunst - Zwischen Kassel und Kabul. Was bringt die 13. Documenta?', 'url': ''}, {'type': 'Publication', 'year': '2012', 'author': ['Stefan Drößler'], 'label': 'Multimediathek - Universitätsbibliothek Kassel', 'url': ''}, {'type': 'Publication', 'year': '2012', 'author': ['Alexander Roßnagel', 'Walter Blocher', 'Christiane Borchard', 'Klaus David', 'Jan Marco Leimeister', 'Andreas Schulz'], 'label': 'Mobiles Ler
# ...

# %%
with open("1.xml", "w") as xml:
    print("<?xml version=\"1.0\" encoding=\"UTF-8\"?>", file=xml)
    print("<liste>", file=xml)
    for item in edited_items:
        print('type', 'label')
        if int(item ["year"])>1980:
            print("\t<item>", file=xml)
            for key in item.keys():
                print("\t\t"+"<"+str(key)+">"+str(item[key])+"<\\"+str(key)+">", file=xml)
            print("\t<\\item>", file=xml)
    print("<\\liste>\n", file=xml)
# Out:
# type label
# type label
# type label
# type label
# type label
# type label
# type label

# %%
! cat 1.xml
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <liste>
# 	<item>
# 		<type>Publication<\type>
# 		<year>2012<\year>
# 		<publisher>Kassel University Press<\publisher>
# 		<author>['Sebastian Böttger']<\author>
# 		<label>Ein Schauspiel in drei Akten: Der Kampf gegen Studiengebühren – 2006 bis 2008<\label>
# 		<url>http://www.upress.uni-kassel.de/katalog/abstract.php?978-3-86219-250-2<\url>
# 	<\item>
# 	<item>
# 		<type>Publication<\type>
# 		<year>2013<\year>
# 		<publisher>euregioverlag<\publisher>
# 		<label>Vom Königshof zur Stadt : Kassel im Mittelalter<\label>
# 		<url>http://deposit.d-nb.de/cgi-bin/dokserv?id=4386411&prov=M&dok_var=1&dok_ext=htm<\url>
# 	<\item>
# 	<item>
# 		<type>Publication<\type>
# 		<year> 2012 <\year>
# 		<author>['Stefan Orth']<\author>
# 		<label>Kunst - Zwischen Kassel und Kabul. Was bringt die 13. Documenta?<\label>
# 		<url><\url>
# 	<\item>
# 	<item>
# 		<type>Publication<\type>
# 		<year>2012<\year>
# 		<author>['Stefan Drößler']<\author>
# ...
