# %%
import json

# %%
with open("library.json", "r") as file:
    data = json.load(file)

# %%
print(json.dumps(data, indent=2)) #hier sind die keys properties und types noch drin
# Out:
# {
#   "items": [
#     {
#       "type": "Bookmark",
#       "id": "https://www.bibsonomy.org/url/57f5480ed28689a7197a4b629cf0e706/mikaelbook",
#       "tags": [
#         "library",
#         "sweden",
#         "software",
#         "lablib",
#         "delicious"
#       ],
#       "intraHash": "57f5480ed28689a7197a4b629cf0e706",
#       "label": "Varf\u00f6r CS Library?",
#       "user": "mikaelbook",
#       "description": "Teknikhusets reklamf\u00f6r sin produkt : \"Efter fyra \u00e5rs utveckling och ov\u00e4rderlig input fr\u00e5n alla v\u00e5ra kunder lanserar vi nu den tredje versionen av CS Library med m\u00e5nga fantastiska nyheter. \" \"V\u00e4lkommen till nya CS Library 3! OLA, Open Library Access ger bi",
#       "date": "2014-10-14 15:31:30",
#       "changeDate": "2014-10-14 15:31:30",
#       "count": 1,
#       "url": "http://www.cslibrary.se/varfor-cs-library"
#     },
#     {
#       "type": "Bookmark",
# ...

# %%
import requests

# %%
print(data.keys())
# Out:
# dict_keys(['items'])

# %%
data.pop('properties', None) #key "properties" rausschmeissen

# %%
data.pop('types', None) #key "types" rausschmeissen

# %%
print(json.dumps(data, indent=2))
# Out:
# {
#   "items": [
#     {
#       "type": "Bookmark",
#       "id": "https://www.bibsonomy.org/url/57f5480ed28689a7197a4b629cf0e706/mikaelbook",
#       "tags": [
#         "library",
#         "sweden",
#         "software",
#         "lablib",
#         "delicious"
#       ],
#       "intraHash": "57f5480ed28689a7197a4b629cf0e706",
#       "label": "Varf\u00f6r CS Library?",
#       "user": "mikaelbook",
#       "description": "Teknikhusets reklamf\u00f6r sin produkt : \"Efter fyra \u00e5rs utveckling och ov\u00e4rderlig input fr\u00e5n alla v\u00e5ra kunder lanserar vi nu den tredje versionen av CS Library med m\u00e5nga fantastiska nyheter. \" \"V\u00e4lkommen till nya CS Library 3! OLA, Open Library Access ger bi",
#       "date": "2014-10-14 15:31:30",
#       "changeDate": "2014-10-14 15:31:30",
#       "count": 1,
#       "url": "http://www.cslibrary.se/varfor-cs-library"
#     },
#     {
#       "type": "Bookmark",
# ...

# %%
with open('bibsonomy_Muenich_3.json', 'w') as outfile:
    json.dump(data, outfile, indent=4)
