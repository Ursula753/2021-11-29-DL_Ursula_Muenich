# %%
# Häufigkeiten
import pandas as pd
df = pd.read_csv("../data/Library_Usage.csv")
df.columns
# Out:
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Outside of County', 'Supervisor District'],
#       dtype='object')

# %%
# absolute Häufigkeiten
df['Year Patron Registered'].value_counts()
# Out:
# 2003    69257
# 2015    53951
# 2014    51902
# 2013    48251
# 2012    37395
# 2011    26531
# 2016    26288
# 2010    24321
# 2009    22307
# 2008    20518
# 2007    13289
# 2006    10776
# 2005     9668
# 2004     8994
# Name: Year Patron Registered, dtype: int64

# %%
# relative Häufigkeiten
# 11 Prozent wurden 2013 registriert.Ähnliche hohe Zahlen in den darauffolgenden zwei Jahren.  
# Ausreißer mit 16 Prozent im Jahr 2003.
df['Year Patron Registered'].value_counts(normalize=True)
# Out:
# 2003    0.163555
# 2015    0.127409
# 2014    0.122570
# 2013    0.113948
# 2012    0.088311
# 2011    0.062655
# 2016    0.062081
# 2010    0.057436
# 2009    0.052679
# 2008    0.048455
# 2007    0.031383
# 2006    0.025448
# 2005    0.022832
# 2004    0.021240
# Name: Year Patron Registered, dtype: float64

# %%
df.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 0                  ADULT                0               0
# 1                 0                  ADULT               31              22
# 2                 0                  ADULT                0               0
# 3                 0                  ADULT                0               0
# 4                 0                  ADULT              126              11
#
#         Age Range Home Library Code Home Library Definition  \
# 0  20 to 24 years                P1                    Park
# 1  25 to 34 years                S7                  Sunset
# 2  45 to 54 years                P1                    Park
# 3  25 to 34 years                 X            Main Library
# 4  45 to 54 years                M2                  Marina
#
#   Circulation Active Month Circulation Active Year Notice Preference Code  \
# ...

# %%
x = ("Age Range" == '25 to 34 years').count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7621/390578282.py in <module>
# ----> 1 x = ("Age Range" == '25 to 34 years').count()
#
# AttributeError: 'bool' object has no attribute 'count'

# %%
# 21 Prozent sind zwischen 25 und 34 Jahren
df['Age Range'].value_counts(normalize=True)
# Out:
# 25 to 34 years       0.215208
# 35 to 44 years       0.159227
# 10 to 19 years       0.139271
# 45 to 54 years       0.124026
# 0 to 9 years         0.090357
# 65 to 74 years       0.071216
# 20 to 24 years       0.070318
# 55 to 59 years       0.050161
# 60 to 64 years       0.046783
# 75 years and over    0.033433
# Name: Age Range, dtype: float64

# %%
age_mode = df['Age Range'].mode()
age_mode[0]
# Out:
# '25 to 34 years'

# %%
# Ersetze NaN durch Modus
# df.fillna('25 to 34 years') axis : {1}
values = {'Age Range': '25 to 34 years'}
df.fillna(value=values)
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...

# %%
# hat nicht geklappt, oder? Immer noch 21 Prozent
df['Age Range'].value_counts(normalize=True)
# Out:
# 25 to 34 years       0.215208
# 35 to 44 years       0.159227
# 10 to 19 years       0.139271
# 45 to 54 years       0.124026
# 0 to 9 years         0.090357
# 65 to 74 years       0.071216
# 20 to 24 years       0.070318
# 55 to 59 years       0.050161
# 60 to 64 years       0.046783
# 75 years and over    0.033433
# Name: Age Range, dtype: float64
