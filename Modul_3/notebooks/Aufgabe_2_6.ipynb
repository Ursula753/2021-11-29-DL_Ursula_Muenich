# %%
import pandas as pd
df = pd.read_csv("../data/Library_Usage.csv")
df.loc[df['Total Checkouts'] > 10000]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 851                    9                SPECIAL            18064
# 1963                   0                  ADULT            10521
# 3499                   0                  ADULT            12740
# 20042                  3                 SENIOR            16060
# 31315                  0                  ADULT            13784
# 39585                  0                  ADULT            11086
# 57239                  0                  ADULT            10906
# 86662                  3                 SENIOR            11748
# 117628                 0                  ADULT            11817
# 120604                 3                 SENIOR            10108
# 129341                 3                 SENIOR            12757
# 138351                 0                  ADULT            10809
# 145600                 3                 SENIOR            11871
# ...

# %%
row_filter = (df['Patron Type Definition'] == 'SENIOR') & (df['Notice Preference Definition'] == 'email')
df.loc[row_filter]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 5                      3                 SENIOR                0
# 62                     3                 SENIOR              193
# 176                    3                 SENIOR                7
# 260                    3                 SENIOR              341
# 294                    3                 SENIOR               67
# ...                  ...                    ...              ...
# 423359                 3                 SENIOR                4
# 423388                 3                 SENIOR               25
# 423403                 3                 SENIOR              458
# 423405                 3                 SENIOR              280
# 423431                 3                 SENIOR                0
#
#         Total Renewals          Age Range Home Library Code  \
# 5                    0     65 to 74 years                C2
# 62                  90     65 to 74 years                A5
# ...

# %%
filter1 = (df['Total Checkouts'] >= 20) & (df['Total Checkouts'] <= 80)
filter2 =  df['Total Checkouts'].between(20, 80)
all(filter1 == filter2)
# Out:
# True

# %%
filter3 = (df[df['Age Range'] == '0 to 9 years'])
len(filter3)
print(len(filter3))
# Out:
# 38242

# %%
filter4 = (df[df['Total Checkouts'] > 20000])
print(filter4)
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 146615                 0                  ADULT            24093
# 163893                 3                 SENIOR            25223
# 293371                 0                  ADULT            35907
#
#         Total Renewals       Age Range Home Library Code  \
# 146615             383  45 to 54 years                 X
# 163893             448  65 to 74 years                 X
# 293371             116  35 to 44 years                V3
#
#        Home Library Definition Circulation Active Month  \
# 146615            Main Library                     July
# 163893            Main Library                     July
# 293371       Visitacion Valley                     July
#
#        Circulation Active Year Notice Preference Code  \
# 146615                    2016                      p
# 163893                    2016                      p
# 293371                    2016                      p
#
# ...

# %%
df["Supervisor District"]=pd.to_numeric ( df['Supervisor District'], errors='coerce')
df['Supervisor District']
# Out:
# 0         5.0
# 1         4.0
# 2         NaN
# 3         3.0
# 4         2.0
#          ...
# 423443    9.0
# 423444    6.0
# 423445    9.0
# 423446    9.0
# 423447    8.0
# Name: Supervisor District, Length: 423448, dtype: float64

# %%
Series = pd.Series(['Supervisor District'])
# Series = 'Supervisor District'
result = Series.isin([1, 2, 3])
print(result)
# Out:
# 0    False
# dtype: bool

# %%
print(len(df[df['Supervisor District'].isin([1, 2, 3])]))

# alternative
df['Supervisor District'].isin([1, 2, 3]).sum()
# Out:
# 70091
# 70091
